# %% [markdown]
# ### Imports and API Key

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import os
import re
from alive_progress import alive_bar

# The Guardian API key
keyG = "fad78733-31a0-4ea7-8823-ba815b578899"

# %% [markdown]
# ### Useful functions and API query setup

# %%
# Directories
ROOT_DIR = os.path.dirname(os.path.abspath("__file__"))
PARENT_DIR = os.path.dirname(ROOT_DIR)

# Function that clears text of a dict of substrings
def replace_all(text, dic):
    for i, j in dic.items():
        text = text.replace(i, j)
    return text


# Function that returns the number of articles in the current API query page
def numArticlesInPage(json):
    if json["response"]["total"] - json["response"]["startIndex"] >= 200:
        return 200
    else:
        return json["response"]["total"] - json["response"]["startIndex"] + 1


# Query setup function
def guardian(page):
    return requests.get(
    "https://content.guardianapis.com/search?api-key=" + keyG + 
    "&from-date=2022-02-01" + 
    "&type=article" + 
    "&page=" + str(page) + 
    "&tag=world/ukraine" + 
    "&order-by=newest" + 
    "&show-fields=body" + 
    "&page-size=200"
    )


# Dict of undesirable substrings
rep = {
    "Sign up to First Edition, our free daily newsletter – every weekday morning at 7am": "",
    "Sign up to First Edition, our free daily newsletter – every weekday at 7am BST": "",
    "Sign up to receive Guardian Australia’s fortnightly Rural Network email newsletter": "",
    "Sign up for the Rural Network email newsletter Join the Rural Network group on Facebook to be part of the community": "",
    "Sign up to the daily Business Today email or follow Guardian Business on Twitter at @BusinessDesk": "",
    "Photograph:": "",
    "Related:": "",
}

# Instancing a query to fetch basic information
json_guardian = guardian(14).json()
numPages = json_guardian["response"]["pages"]
numArticles = json_guardian["response"]["total"]
# print(json.dumps(json_guardian, indent=2))

print(f"-> There are {numArticles} articles in {numPages} pages for the period and tags specified.")
# Out:
# -> There are 2660 articles in 14 pages for the period and tags specified.

# %% [markdown]
# ### API Query

# %%
# Instancing
urls = []
titles = []
bodies = []
dates = []

# Scraper
with alive_bar(numArticles, title="-> API Query", spinner="dots_waves", bar="smooth", force_tty=True) as bar:

    # Going through all pages available for the query
    for i in range(1, numPages + 1):

        json_guardian = guardian(i).json()

        # Going through all articles in a page
        for j in range(0, numArticlesInPage(json_guardian)):

            urls.append(json_guardian["response"]["results"][j]["webUrl"])
            dates.append(json_guardian["response"]["results"][j]["webPublicationDate"])

            title = json_guardian["response"]["results"][j]["webTitle"]
            titles.append(re.sub(r"\|.*$", "", title)) # removing authors from titles
            
            body = BeautifulSoup(json_guardian["response"]["results"][j]["fields"]["body"], "html.parser").get_text()
            body = replace_all(body, rep)  # replacing substrings
            bodies.append(re.sub(r"[\t\r\n]", "", body)) # removing line breaks
            bar()

# Transforming fetched info to dataframe
data = pd.DataFrame({"URL": urls, "Date": dates, "Title": titles, "Text": bodies})

# Saving to csv
os.makedirs(PARENT_DIR + "/data", exist_ok=True)
data.to_csv(PARENT_DIR + "/data/guardian.csv", index=True, header=True)

print(f"-> {len(data)} articles fetched successfully!")
# Out:
# -> API Query |████████████████████████████████████████| 2660/2660 [100%] in 40.4s (65.78/s)
# -> 2660 articles fetched successfully!

# %%
data.head(25)
# Out:
#                                                   URL                  Date  \
# 0   https://www.theguardian.com/world/2022/jun/17/...  2022-06-17T16:43:26Z
# 1   https://www.theguardian.com/politics/2022/jun/...  2022-06-17T15:57:58Z
# 2   https://www.theguardian.com/tv-and-radio/2022/...  2022-06-17T14:11:10Z
# 3   https://www.theguardian.com/world/2022/jun/17/...  2022-06-17T12:15:51Z
# 4   https://www.theguardian.com/world/2022/jun/17/...  2022-06-17T11:51:35Z
# 5   https://www.theguardian.com/world/2022/jun/17/...  2022-06-17T00:31:37Z
# 6   https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T16:59:27Z
# 7   https://www.theguardian.com/law/2022/jun/16/ru...  2022-06-16T16:28:07Z
# 8   https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T15:16:27Z
# 9   https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T13:13:29Z
# 10  https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T09:55:42Z
# 11  https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T04:00:49Z
# 12  https://www.theguardian.com/us-news/2022/jun/1...  2022-06-16T00:12:21Z
# 13  https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T00:01:33Z
# 14  https://www.theguardian.com/uk-news/2022/jun/1...  2022-06-15T22:53:21Z
# 15  https://www.theguardian.com/world/2022/jun/15/...  2022-06-15T16:38:58Z
# 16  https://www.theguardian.com/business/2022/jun/...  2022-06-15T14:08:47Z
# 17  https://www.theguardian.com/world/2022/jun/15/...  2022-06-15T12:28:46Z
# 18  https://www.theguardian.com/news/2022/jun/15/o...  2022-06-15T08:00:25Z
# 19  https://www.theguardian.com/world/2022/jun/15/...  2022-06-15T04:00:20Z
# 20  https://www.theguardian.com/world/2022/jun/15/...  2022-06-15T04:00:20Z
# 21  https://www.theguardian.com/world/2022/jun/15/...  2022-06-15T00:37:22Z
# 22  https://www.theguardian.com/commentisfree/2022...  2022-06-14T18:07:10Z
# 23  https://www.theguardian.com/media/2022/jun/14/...  2022-06-14T17:07:26Z
# 24  https://www.theguardian.com/world/2022/jun/14/...  2022-06-14T16:37:08Z
#
#                                                 Title  \
# 0   France and Turkey propose rival plans to get g...
# 1   Boris Johnson promises Ukraine UK-led troop tr...
# 2   UK is asked to host Eurovision in 2023 after U...
# 3   EU says Ukraine should be given candidate stat...
# 4   Third American volunteer fighter reported miss...
# 5   Russia-Ukraine war: what we know on day 114 of...
# 6   Scholz, Macron and Draghi vow support for Ukra...
# 7   Russian spy caught trying to infiltrate war cr...
# 8   Hundreds of Ukrainian refugees left homeless i...
# 9   UK aims sanctions at Russians accused of abduc...
# 10  Plan needed to make Russia pay reparations to ...
# 11  ‘It was worse than hell’: life in Mariupol und...
# 12  Two US volunteers in Ukraine feared taken pris...
# 13  Russia-Ukraine war: what we know on day 113 of...
# 14  Ex-Russian football captain Igor Denisov conde...
# 15  Ukraine ignores Russian ultimatum to surrender...
# 16  Russia rakes in nearly $20bn from oil exports ...
# 17  US announces plan to build silos on Ukraine bo...
# 18    On the line: Inside the 17 June Guardian Weekly
# 19  RHS garden with burnt-out cottage ‘shows Ukrai...
# 20  ‘Justice’ for Ukraine overshadowed by cost of ...
# 21  Russia-Ukraine war: what we know on day 112 of...
# 22  The Guardian view on Ukraine’s suffering: no e...
# 23  Russia bans 29 UK journalists, including Guard...
# 24  Sievierodonetsk evacuation continues despite l...
#
#                                                  Text
# 0   Rival plans to export Ukraine’s vitally needed...
# 1   Boris Johnson has announced that the UK will o...
# 2   The UK has been offered the chance to host Eur...
# 3   The European Commission has said Ukraine shoul...
# 4   A third American volunteer fighting in Ukraine...
# 5    The EU’s executive arm has recommended that U...
# 6   The leaders of France, Germany and Italy have ...
# 7   A Russian spy tried and failed to secure an in...
# 8   Hundreds of Ukrainian families have been left ...
# 9   A fresh wave of sanctions against Russia has b...
# 10  Western and Ukrainian rhetoric claiming Russia...
# 11  A month after the end of the siege at Mariupol...
# 12  Two American volunteers in Ukraine have gone m...
# 13   French President Emmanuel Macron praised the ...
# 14  Igor Denisov, the former captain of Russia’s n...
# 15  Ukraine has ignored a Russian ultimatum to sur...
# 16  Russia raked in around $20bn (£16.6bn) from oi...
# 17  Temporary silos will be built along the Ukrain...
# 18  In recent weeks the focus of the war in Ukrain...
# 19  A burnt-out cottage decorated with embroidered...
# 20  Europe’s unity over the war in Ukraine is at r...
# 21   Some 500 civilians believed to be trapped alo...
# 22  In the hours following Moscow’s invasion of Uk...
# 23  Russia has banned 29 members of the British me...
# 24  Ukrainian authorities say they are continuing ...

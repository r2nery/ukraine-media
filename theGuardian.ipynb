# %% [markdown]
# ### Imports and API Key

# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
import os
import re
from alive_progress import alive_bar

# The Guardian API key
keyG = "fad78733-31a0-4ea7-8823-ba815b578899"

# %% [markdown]
# ### Useful functions and API query setup

# %%
# Function that clears text of a dict of substrings
def replace_all(text, dic):
    for i, j in dic.items():
        text = text.replace(i, j)
    return text


# Function that returns the number of articles in the current API query page
def numArticlesInPage(json):
    if json["response"]["total"] - json["response"]["startIndex"] >= 200:
        return 200
    else:
        return json["response"]["total"] - json["response"]["startIndex"] + 1


# Query setup function
def guardian(page):
    return requests.get(
    "https://content.guardianapis.com/search?api-key=" + keyG + 
    "&from-date=2022-02-01" + 
    "&type=article" + 
    "&page=" + str(page) + 
    "&tag=world/ukraine" + 
    "&order-by=newest" + 
    "&show-fields=body" + 
    "&page-size=200"
    )


# Dict of undesirable substrings
rep = {
    "Sign up to First Edition, our free daily newsletter – every weekday morning at 7am": "",
    "Sign up to First Edition, our free daily newsletter – every weekday at 7am BST": "",
    "Sign up to receive Guardian Australia’s fortnightly Rural Network email newsletter": "",
    "Sign up for the Rural Network email newsletter Join the Rural Network group on Facebook to be part of the community": "",
    "Sign up to the daily Business Today email or follow Guardian Business on Twitter at @BusinessDesk": "",
    "Photograph:": "",
    "Related:": "",
}

# Instancing a query to fetch basic information
json_guardian = guardian(14).json()
numPages = json_guardian["response"]["pages"]
numArticles = json_guardian["response"]["total"]
# print(json.dumps(json_guardian, indent=2))

print(f"-> There are {numArticles} articles in {numPages} pages for the period and tags specified.")
# Out:
# -> There are 2655 articles in 14 pages for the period and tags specified.

# %% [markdown]
# ### API Query

# %%
# Instancing
urls = []
titles = []
bodies = []
dates = []

# Scraper
with alive_bar(numArticles, title="-> API Query", spinner="dots_waves", bar="smooth", force_tty=True) as bar:

    # Going through all pages available for the query
    for page in range(1, numPages + 1):

        json_guardian = guardian(page).json()

        # Going through all articles in a page
        for i in range(0, numArticlesInPage(json_guardian)):

            urls.append(json_guardian["response"]["results"][i]["webUrl"])
            titles.append(json_guardian["response"]["results"][i]["webTitle"])
            dates.append(json_guardian["response"]["results"][i]["webPublicationDate"])
            soup = BeautifulSoup(json_guardian["response"]["results"][i]["fields"]["body"], "html.parser").get_text()

            soup = replace_all(soup, rep)  # replacing substrings
            soup = re.sub(r"[\t\r\n]", "", soup)  # removing line breaks
            bodies.append(soup)
            bar()

# Transforming fetched info to dataframe
dict_data = {"URL": urls, "Date": dates, "Title": titles, "Text": bodies}
data = pd.DataFrame(dict_data)

# Saving to csv
os.makedirs(os.getcwd() + "/data", exist_ok=True)
data.to_csv("data/guardian.csv", index=True, header=True)

print(f"-> {len(data)} articles fetched successfully!")

# %%
data.head(25)
# Out:
#                                                   URL                  Date  \
# 0   https://www.theguardian.com/world/2022/jun/17/...  2022-06-17T00:31:37Z
# 1   https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T16:59:27Z
# 2   https://www.theguardian.com/law/2022/jun/16/ru...  2022-06-16T16:28:07Z
# 3   https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T15:16:27Z
# 4   https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T13:13:29Z
# 5   https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T09:55:42Z
# 6   https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T04:00:49Z
# 7   https://www.theguardian.com/us-news/2022/jun/1...  2022-06-16T00:12:21Z
# 8   https://www.theguardian.com/world/2022/jun/16/...  2022-06-16T00:01:33Z
# 9   https://www.theguardian.com/uk-news/2022/jun/1...  2022-06-15T22:53:21Z
# 10  https://www.theguardian.com/world/2022/jun/15/...  2022-06-15T16:38:58Z
# 11  https://www.theguardian.com/business/2022/jun/...  2022-06-15T14:08:47Z
# 12  https://www.theguardian.com/world/2022/jun/15/...  2022-06-15T12:28:46Z
# 13  https://www.theguardian.com/news/2022/jun/15/o...  2022-06-15T08:00:25Z
# 14  https://www.theguardian.com/world/2022/jun/15/...  2022-06-15T04:00:20Z
# 15  https://www.theguardian.com/world/2022/jun/15/...  2022-06-15T04:00:20Z
# 16  https://www.theguardian.com/world/2022/jun/15/...  2022-06-15T00:37:22Z
# 17  https://www.theguardian.com/commentisfree/2022...  2022-06-14T18:07:10Z
# 18  https://www.theguardian.com/media/2022/jun/14/...  2022-06-14T17:07:26Z
# 19  https://www.theguardian.com/world/2022/jun/14/...  2022-06-14T16:37:08Z
# 20  https://www.theguardian.com/global-development...  2022-06-14T13:30:16Z
# 21  https://www.theguardian.com/world/2022/jun/14/...  2022-06-14T11:20:02Z
# 22  https://www.theguardian.com/world/2022/jun/14/...  2022-06-14T10:34:44Z
# 23  https://www.theguardian.com/world/2022/jun/14/...  2022-06-14T00:09:36Z
# 24  https://www.theguardian.com/world/2022/jun/13/...  2022-06-13T17:29:24Z
#
#                                                 Title  \
# 0   Russia-Ukraine war: what we know on day 114 of...
# 1   Scholz, Macron and Draghi vow support for Ukra...
# 2   Russian spy caught trying to infiltrate war cr...
# 3   Hundreds of Ukrainian refugees left homeless i...
# 4   UK aims sanctions at Russians accused of abduc...
# 5   Plan needed to make Russia pay reparations to ...
# 6   ‘It was worse than hell’: life in Mariupol und...
# 7   Two US volunteers in Ukraine feared taken pris...
# 8   Russia-Ukraine war: what we know on day 113 of...
# 9   Ex-Russian football captain Igor Denisov conde...
# 10  Ukraine ignores Russian ultimatum to surrender...
# 11  Russia rakes in nearly $20bn from oil exports ...
# 12  US announces plan to build silos on Ukraine bo...
# 13    On the line: Inside the 17 June Guardian Weekly
# 14  RHS garden with burnt-out cottage ‘shows Ukrai...
# 15  ‘Justice’ for Ukraine overshadowed by cost of ...
# 16  Russia-Ukraine war: what we know on day 112 of...
# 17  The Guardian view on Ukraine’s suffering: no e...
# 18  Russia bans 29 UK journalists, including Guard...
# 19  Sievierodonetsk evacuation continues despite l...
# 20  Millions at risk in South Sudan as Ukraine war...
# 21  Pope Francis says Ukraine war was ‘perhaps som...
# 22  ‘I could not be part of this crime’: the Russi...
# 23  Russia-Ukraine war: what we know on day 111 of...
# 24  Fears grow for Sievierodonetsk civilians as pl...
#
#                                                  Text
# 0    Hundreds of civilians sheltering at the Azot ...
# 1   The leaders of France, Germany and Italy have ...
# 2   A Russian spy tried and failed to secure an in...
# 3   Hundreds of Ukrainian families have been left ...
# 4   A fresh wave of sanctions against Russia has b...
# 5   Western and Ukrainian rhetoric claiming Russia...
# 6   A month after the end of the siege at Mariupol...
# 7   Two American volunteers in Ukraine have gone m...
# 8    French President Emmanuel Macron praised the ...
# 9   Igor Denisov, the former captain of Russia’s n...
# 10  Ukraine has ignored a Russian ultimatum to sur...
# 11  Russia raked in around $20bn (£16.6bn) from oi...
# 12  Temporary silos will be built along the Ukrain...
# 13  In recent weeks the focus of the war in Ukrain...
# 14  A burnt-out cottage decorated with embroidered...
# 15  Europe’s unity over the war in Ukraine is at r...
# 16   Some 500 civilians believed to be trapped alo...
# 17  In the hours following Moscow’s invasion of Uk...
# 18  Russia has banned 29 members of the British me...
# 19  Ukrainian authorities say they are continuing ...
# 20  The World Food Programme has said it is suspen...
# 21  Pope Francis has said Moscow’s invasion of Ukr...
# 22  Walking around Kyiv in his new Ukrainian milit...
# 23   Ukraine’s president, Volodymyr Zelenskiy, has...
# 24  Russian artillery is hitting an industrial zon...
